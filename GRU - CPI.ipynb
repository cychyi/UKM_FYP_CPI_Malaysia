# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout, GRU, Bidirectional
from tensorflow.keras.optimizers import SGD
import math
from sklearn.metrics import mean_squared_error

# %%
# Some functions to help out with
def plot_predictions(test,predicted):
    plt.plot(test, color='red',label='Actual CPI Value')
    plt.plot(predicted, color='blue',label='Predicted CPI Value')
    plt.title("Malaysia's CPI Value")
    plt.xlabel('Date')
    plt.ylabel('CPI')
    plt.legend()
    plt.show()

def return_rmse(test,predicted):
    rmse = math.sqrt(mean_squared_error(test, predicted))
    print("The root mean squared error is {}.".format(rmse))
    
def return_analysis(test,predicted):
    e=predicted-test
    mse_f = np.mean(e**2)
    mae_f = np.mean(abs(e))
    mape_f = np.mean(abs(e/predicted))*100
    rmse_f = np.sqrt(mse_f)
    r2_f = 1-(sum(e**2)/sum((predicted-np.mean(predicted))**2))
    print("The root mean squared error is {}.".format(rmse_f))
    print("The mean absolute error is {}.".format(mae_f))
    print("The mean absolute percentage error is {}.".format(mape_f), "%")

# %%
# Read in the weather data csv - keep only the columns we need
df=pd.read_csv('/Users/chamyingchyi/Desktop/Academic Purpose/FYP/Dataset/Cleaned_Data.csv', encoding='utf-8')
df1=df[["Date","CPI"]]
df2=df1[0:657]
print(df2)
# Out:
#        Date    CPI
# 0    Jan-68   23.4
# 1    Feb-68   23.3
# 2    Mar-68   23.3
# 3    Apr-68   23.2
# 4    May-68   23.0
# ..      ...    ...
# 652  May-22  126.6
# 653  Jun-22  127.4
# 654  Jul-22  127.9
# 655  Aug-22  128.2
# 656  Sep-22  128.3
#
# [657 rows x 2 columns]

# %%
# Checking for missing values
training_set = df2.iloc[0:525,1:2].values
test_set =df2.iloc[525:657,1:2].values

print(training_set,test_set)
# Out:
# [[ 23.4]
#  [ 23.3]
#  [ 23.3]
#  [ 23.2]
#  [ 23. ]
#  [ 22.8]
#  [ 22.8]
#  [ 22.7]
#  [ 22.7]
#  [ 22.7]
#  [ 22.7]
#  [ 22.7]
#  [ 22.7]
#  [ 22.7]
#  [ 22.7]
#  [ 22.6]
#  [ 22.7]
#  [ 22.7]
#  [ 22.7]
#  [ 22.7]
#  [ 23. ]
#  [ 23. ]
#  [ 23.2]
#  [ 23.3]
#  [ 23.4]
#  [ 23.4]
#  [ 23.3]
#  [ 23.3]
#  [ 23.3]
#  [ 23.3]
#  [ 23.4]
#  [ 23.3]
#  [ 23.4]
#  [ 23.4]
#  [ 23.5]
#  [ 23.5]
#  [ 23.9]
#  [ 24. ]
#  [ 23.8]
#  [ 23.6]
#  [ 23.5]
#  [ 23.5]
#  [ 23.4]
#  [ 23.5]
#  [ 23.6]
#  [ 23.9]
#  [ 24. ]
#  [ 24.2]
#  [ 24.3]
#  [ 24.3]
#  [ 24.3]
#  [ 24.4]
#  [ 24.3]
#  [ 24.4]
#  [ 24.5]
#  [ 24.5]
#  [ 24.6]
#  [ 24.6]
#  [ 24.7]
#  [ 25. ]
#  [ 25.3]
#  [ 25.5]
#  [ 25.5]
#  [ 25.8]
#  [ 26.4]
#  [ 26.7]
#  [ 27.2]
#  [ 27.5]
#  [ 28.1]
#  [ 28.5]
#  [ 29.2]
#  [ 29.6]
#  [ 29.9]
#  [ 30.9]
#  [ 31.5]
#  [ 31.2]
#  [ 31.5]
#  [ 31.7]
#  [ 31.9]
#  [ 32.2]
#  [ 32.3]
#  [ 32.5]
#  [ 32.9]
#  [ 33.2]
#  [ 33.4]
#  [ 33.5]
#  [ 33.1]
#  [ 33. ]
#  [ 33. ]
#  [ 33. ]
#  [ 33. ]
#  [ 33.2]
#  [ 33.4]
#  [ 33.3]
#  [ 33. ]
#  [ 33.5]
#  [ 33.9]
#  [ 33.6]
#  [ 33.7]
#  [ 33.6]
#  [ 33.7]
#  [ 34.1]
#  [ 34.1]
#  [ 34.2]
#  [ 34.3]
#  [ 34.3]
#  [ 34.3]
#  [ 34.8]
#  [ 35.3]
#  [ 35.3]
#  [ 35.3]
#  [ 35.1]
#  [ 35.3]
#  [ 35.4]
#  [ 35.6]
#  [ 35.9]
#  [ 36.2]
#  [ 36.2]
#  [ 36.4]
#  [ 36.6]
#  [ 36.6]
#  [ 36.9]
#  [ 36.7]
#  [ 36.7]
#  [ 37. ]
#  [ 37.6]
#  [ 37.5]
#  [ 38.1]
#  [ 38.1]
#  [ 38.1]
#  [ 38.1]
#  [ 38.1]
#  [ 38.1]
#  [ 38.2]
#  [ 38.3]
#  [ 38.3]
#  [ 38.6]
#  [ 38.6]
#  [ 38.8]
#  [ 39.1]
#  [ 39.4]
#  [ 39.3]
#  [ 39.5]
#  [ 40.1]
#  [ 40.2]
#  [ 40.4]
#  [ 40.4]
#  [ 40.2]
#  [ 40.6]
#  [ 41. ]
#  [ 41.3]
#  [ 41.7]
#  [ 41.6]
#  [ 41.8]
#  [ 42.4]
#  [ 42.7]
#  [ 43.5]
#  [ 44. ]
#  [ 44.4]
#  [ 44.6]
#  [ 44.8]
#  [ 45.1]
#  [ 45.5]
#  [ 45.8]
#  [ 46. ]
#  [ 46. ]
#  [ 46.1]
#  [ 46.3]
#  [ 46.8]
#  [ 47.1]
#  [ 47.2]
#  [ 47.4]
#  [ 47.5]
#  [ 47.7]
#  [ 48. ]
#  [ 48.1]
#  [ 48.1]
#  [ 48. ]
#  [ 48.5]
#  [ 48.7]
#  [ 49.2]
#  [ 49. ]
#  [ 49.1]
#  [ 49.1]
#  [ 49.4]
#  [ 49.5]
#  [ 49.6]
#  [ 49.6]
#  [ 49.8]
#  [ 49.9]
#  [ 50. ]
#  [ 50.3]
#  [ 51.2]
#  [ 51.8]
#  [ 51.1]
#  [ 51.1]
#  [ 51.1]
#  [ 51.1]
#  [ 51.5]
#  [ 51.5]
#  [ 51.5]
#  [ 51.4]
#  [ 51.1]
#  [ 51.1]
#  [ 51.2]
#  [ 51.3]
#  [ 51.4]
#  [ 51.3]
#  [ 51.3]
#  [ 51.5]
#  [ 51.8]
#  [ 51.9]
#  [ 51.7]
#  [ 51.5]
#  [ 51.5]
#  [ 51.7]
#  [ 51.8]
#  [ 51.9]
#  [ 51.8]
#  [ 51.5]
#  [ 51.7]
#  [ 51.7]
#  [ 51.7]
#  [ 51.7]
#  [ 51.8]
#  [ 51.9]
#  [ 52.1]
#  [ 52.2]
#  [ 52.1]
#  [ 52.1]
#  [ 51.9]
#  [ 52.1]
#  [ 52.2]
#  [ 52.3]
#  [ 52.2]
#  [ 52.2]
#  [ 52.3]
#  [ 52.4]
#  [ 52.5]
#  [ 52.7]
#  [ 52.8]
#  [ 52.9]
#  [ 53. ]
#  [ 53. ]
#  [ 53. ]
#  [ 53.5]
#  [ 53.9]
#  [ 53.9]
#  [ 54. ]
#  [ 53.9]
#  [ 54.2]
#  [ 54.6]
#  [ 54.6]
#  [ 54.6]
#  [ 54.6]
#  [ 54.7]
#  [ 54.9]
#  [ 54.9]
#  [ 55.1]
#  [ 55.2]
#  [ 55.3]
#  [ 55.3]
#  [ 55.6]
#  [ 55.8]
#  [ 56.1]
#  [ 56.3]
#  [ 56.3]
#  [ 56.6]
#  [ 56.8]
#  [ 56.7]
#  [ 56.6]
#  [ 56.5]
#  [ 56.8]
#  [ 57.2]
#  [ 57.5]
#  [ 57.8]
#  [ 58. ]
#  [ 58.3]
#  [ 58.5]
#  [ 58.9]
#  [ 59.1]
#  [ 59.6]
#  [ 59.4]
#  [ 59.5]
#  [ 59.4]
#  [ 59.6]
#  [ 59.9]
#  [ 60.4]
#  [ 60.6]
#  [ 60.9]
#  [ 61.1]
#  [ 61.5]
#  [ 62.1]
#  [ 62.2]
#  [ 62.3]
#  [ 62.5]
#  [ 62.5]
#  [ 62.5]
#  [ 63. ]
#  [ 63.2]
#  [ 63.3]
#  [ 63.5]
#  [ 63.6]
#  [ 63.9]
#  [ 64. ]
#  [ 64.2]
#  [ 64.6]
#  [ 64.4]
#  [ 64.4]
#  [ 64.6]
#  [ 64.9]
#  [ 65.4]
#  [ 65.7]
#  [ 66.3]
#  [ 66.1]
#  [ 66.1]
#  [ 66.2]
#  [ 66.1]
#  [ 66.6]
#  [ 66.7]
#  [ 67. ]
#  [ 67.1]
#  [ 67.5]
#  [ 67.7]
#  [ 68. ]
#  [ 68.4]
#  [ 68.3]
#  [ 68.3]
#  [ 68.8]
#  [ 68.8]
#  [ 68.9]
#  [ 69. ]
#  [ 69.3]
#  [ 69.4]
#  [ 69.7]
#  [ 69.9]
#  [ 70.3]
#  [ 70.8]
#  [ 70.5]
#  [ 70.9]
#  [ 71.2]
#  [ 71.3]
#  [ 71.5]
#  [ 71.5]
#  [ 71.8]
#  [ 71.8]
#  [ 72. ]
#  [ 72.2]
#  [ 72.5]
#  [ 72.9]
#  [ 72.8]
#  [ 72.7]
#  [ 73. ]
#  [ 72.9]
#  [ 73. ]
#  [ 73.2]
#  [ 73.4]
#  [ 73.7]
#  [ 73.9]
#  [ 74.3]
#  [ 75. ]
#  [ 76.1]
#  [ 76.6]
#  [ 76.7]
#  [ 76.9]
#  [ 77.5]
#  [ 77.3]
#  [ 77.4]
#  [ 77.5]
#  [ 77.5]
#  [ 78.1]
#  [ 78.2]
#  [ 78.9]
#  [ 79. ]
#  [ 78.9]
#  [ 78.9]
#  [ 79.2]
#  [ 79.1]
#  [ 79.2]
#  [ 79.1]
#  [ 79.1]
#  [ 79.1]
#  [ 79.4]
#  [ 80.2]
#  [ 80.2]
#  [ 80.3]
#  [ 80.2]
#  [ 80.2]
#  [ 80.3]
#  [ 80.3]
#  [ 80.4]
#  [ 80.4]
#  [ 80.4]
#  [ 80.6]
#  [ 80.8]
#  [ 81.1]
#  [ 81.4]
#  [ 81.5]
#  [ 81.4]
#  [ 81.5]
#  [ 81.5]
#  [ 81.5]
#  [ 81.5]
#  [ 81.4]
#  [ 81.5]
#  [ 81.4]
#  [ 82. ]
#  [ 82.1]
#  [ 82.3]
#  [ 82.5]
#  [ 83.1]
#  [ 83. ]
#  [ 83.1]
#  [ 83.2]
#  [ 83.2]
#  [ 83.1]
#  [ 83.2]
#  [ 83.1]
#  [ 83.3]
#  [ 83.4]
#  [ 83.6]
#  [ 83.8]
#  [ 83.6]
#  [ 83.8]
#  [ 83.9]
#  [ 83.8]
#  [ 83.9]
#  [ 83.9]
#  [ 84. ]
#  [ 84.1]
#  [ 84.2]
#  [ 84.4]
#  [ 84.4]
#  [ 84.5]
#  [ 84.4]
#  [ 84.6]
#  [ 84.8]
#  [ 84.9]
#  [ 85.1]
#  [ 85.1]
#  [ 85.4]
#  [ 85.9]
#  [ 86.1]
#  [ 86.2]
#  [ 86.5]
#  [ 86.6]
#  [ 86.6]
#  [ 86.8]
#  [ 87.5]
#  [ 87.6]
#  [ 87.6]
#  [ 88.2]
#  [ 88.4]
#  [ 88.6]
#  [ 88.9]
#  [ 89. ]
#  [ 89.3]
#  [ 89.4]
#  [ 90.7]
#  [ 90.7]
#  [ 90.9]
#  [ 91.1]
#  [ 91.2]
#  [ 91.1]
#  [ 91.3]
#  [ 91.3]
#  [ 91.6]
#  [ 91.8]
#  [ 92.2]
#  [ 92.2]
#  [ 92.1]
#  [ 92.1]
#  [ 92.2]
#  [ 92.4]
#  [ 92.7]
#  [ 92.9]
#  [ 93. ]
#  [ 93.1]
#  [ 93.7]
#  [ 93.9]
#  [ 94.3]
#  [ 94.6]
#  [ 94.6]
#  [ 94.9]
#  [ 95.7]
#  [ 99.5]
#  [100.6]
#  [100.8]
#  [100.6]
#  [100.2]
#  [ 99. ]
#  [ 98.1]
#  [ 98. ]
#  [ 98.2]
#  [ 98. ]
#  [ 97.8]
#  [ 98. ]
#  [ 98.1]
#  [ 98.2]
#  [ 98.3]
#  [ 98.6]
#  [ 98.7]
#  [ 98.9]
#  [ 99.1]
#  [ 99.4]
#  [ 99.4]
#  [ 99.4]
#  [ 99.4]
#  [ 99.6]
#  [ 99.7]
#  [100. ]
#  [100.3]
#  [100.4]
#  [100.6]
#  [100.8]
#  [101.2]
#  [101.8]
#  [102.3]
#  [102.4]
#  [102.6]
#  [102.9]
#  [103.2]
#  [103.4]
#  [103.6]
#  [103.8]] [[104. ]
#  [104.1]
#  [104.2]
#  [104.5]
#  [104.5]
#  [104.5]
#  [104.5]
#  [104.7]
#  [104.8]
#  [104.8]
#  [105. ]
#  [105.2]
#  [105.4]
#  [105.5]
#  [105.5]
#  [105.9]
#  [106.1]
#  [106.2]
#  [106.3]
#  [106.6]
#  [106.7]
#  [106.9]
#  [107. ]
#  [107.9]
#  [108.3]
#  [108.6]
#  [108.9]
#  [109.5]
#  [109.8]
#  [109.9]
#  [109.9]
#  [110. ]
#  [110.2]
#  [110.3]
#  [110.5]
#  [110.7]
#  [111.3]
#  [111.9]
#  [111.8]
#  [110.6]
#  [109.9]
#  [110.9]
#  [111.9]
#  [112.3]
#  [113. ]
#  [113.9]
#  [113.9]
#  [113.6]
#  [114.1]
#  [114.8]
#  [114.8]
#  [114.5]
#  [114.5]
#  [113.8]
#  [114.3]
#  [114.6]
#  [114.8]
#  [115.1]
#  [115.6]
#  [115.3]
#  [115.7]
#  [116.8]
#  [116.8]
#  [118.1]
#  [119.6]
#  [119.4]
#  [119.2]
#  [119. ]
#  [118.7]
#  [118.7]
#  [119.8]
#  [120.1]
#  [120. ]
#  [120.8]
#  [120.9]
#  [121.3]
#  [121.3]
#  [120.9]
#  [120.9]
#  [121.1]
#  [119.6]
#  [119.8]
#  [120. ]
#  [120.5]
#  [120.7]
#  [121. ]
#  [121.1]
#  [120.5]
#  [120.8]
#  [121.1]
#  [121.1]
#  [121.4]
#  [121.4]
#  [121.5]
#  [121.8]
#  [121.8]
#  [122. ]
#  [122.1]
#  [122.3]
#  [122.4]
#  [122.4]
#  [120.9]
#  [117.6]
#  [117.9]
#  [119.1]
#  [119.9]
#  [120.1]
#  [120.1]
#  [120.2]
#  [120. ]
#  [120.6]
#  [122.1]
#  [122.5]
#  [122.9]
#  [123.1]
#  [123.1]
#  [123.2]
#  [122.5]
#  [122.5]
#  [122.8]
#  [123.7]
#  [124. ]
#  [124.5]
#  [124.9]
#  [125.2]
#  [125.6]
#  [125.9]
#  [126.6]
#  [127.4]
#  [127.9]
#  [128.2]
#  [128.3]]

# %%
df2.iloc[0:525,1].plot(figsize=(16,4),legend=True)
df2.iloc[525:657,1].plot(figsize=(16,4),legend=True)
plt.legend(['Training set','Test set'])
plt.title('CPI in Malaysia')
plt.show()

# %%
sc = MinMaxScaler(feature_range=(0,1))
training_set_scaled = sc.fit_transform(training_set)

# %%
# Since GRU store long term memory state, we create a data structure with 60 timesteps and 1 output
# So for each element of training set, we have 60 previous training set elements 
X_train = []
y_train = []
for i in range(60,525):
    X_train.append(training_set_scaled[i-60:i,0])
    y_train.append(training_set_scaled[i,0])
X_train, y_train = np.array(X_train), np.array(y_train)

X_train
# Out:
# array([[0.00985222, 0.00862069, 0.00862069, ..., 0.02463054, 0.02586207,
#         0.02955665],
#        [0.00862069, 0.00862069, 0.00738916, ..., 0.02586207, 0.02955665,
#         0.03325123],
#        [0.00862069, 0.00738916, 0.00492611, ..., 0.02955665, 0.03325123,
#         0.03571429],
#        ...,
#        [0.84482759, 0.84359606, 0.84605911, ..., 0.98522167, 0.98891626,
#         0.99261084],
#        [0.84359606, 0.84605911, 0.84605911, ..., 0.98891626, 0.99261084,
#         0.99507389],
#        [0.84605911, 0.84605911, 0.84975369, ..., 0.99261084, 0.99507389,
#         0.99753695]])

# %%
# Reshaping X_train for efficient modelling
X_train = np.reshape(X_train, (X_train.shape[0],X_train.shape[1],1))

# %%
# The GRU architecture
regressorGRU = Sequential()
# First GRU layer with Dropout regularisation
regressorGRU.add(GRU(units=50, return_sequences=True, input_shape=(X_train.shape[1],1), activation='relu'))
regressorGRU.add(Dropout(0.2))
# Second GRU layer
regressorGRU.add(GRU(units=50, return_sequences=True, input_shape=(X_train.shape[1],1), activation='relu'))
regressorGRU.add(Dropout(0.2))
# Third GRU layer
regressorGRU.add(GRU(units=50, return_sequences=True, input_shape=(X_train.shape[1],1), activation='sigmoid'))
regressorGRU.add(Dropout(0.2))
# Fourth GRU layer
regressorGRU.add(GRU(units=50, activation='tanh'))
regressorGRU.add(Dropout(0.2))
# The output layer
regressorGRU.add(Dense(units=1))
# Compiling the RNN
regressorGRU.compile(optimizer=SGD(lr=0.01, decay=1e-7, momentum=0.9, nesterov=False),loss='mean_squared_error')
# Fitting to the training set
regressorGRU.fit(X_train,y_train,epochs=100,batch_size=64)
# Out:
# Epoch 1/100
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/keras/optimizer_v2/gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)
# 8/8 [==============================] - 9s 191ms/step - loss: 0.5486
# Epoch 2/100
# 8/8 [==============================] - 1s 158ms/step - loss: 0.2390
# Epoch 3/100
# 8/8 [==============================] - 1s 156ms/step - loss: 0.1643
# Epoch 4/100
# 8/8 [==============================] - 1s 148ms/step - loss: 0.1056
# Epoch 5/100
# 8/8 [==============================] - 1s 148ms/step - loss: 0.0910
# Epoch 6/100
# 8/8 [==============================] - 1s 146ms/step - loss: 0.0843
# Epoch 7/100
# 8/8 [==============================] - 1s 148ms/step - loss: 0.0813
# Epoch 8/100
# 8/8 [==============================] - 1s 148ms/step - loss: 0.0785
# Epoch 9/100
# 8/8 [==============================] - 1s 150ms/step - loss: 0.0828
# Epoch 10/100
# 8/8 [==============================] - 1s 141ms/step - loss: 0.0769
# Epoch 11/100
# 8/8 [==============================] - 1s 145ms/step - loss: 0.0797
# Epoch 12/100
# 8/8 [==============================] - 1s 145ms/step - loss: 0.0728
# Epoch 13/100
# 8/8 [==============================] - 1s 144ms/step - loss: 0.0770
# Epoch 14/100
# 8/8 [==============================] - 1s 143ms/step - loss: 0.0720
# Epoch 15/100
# 8/8 [==============================] - 1s 141ms/step - loss: 0.0811
# Epoch 16/100
# 8/8 [==============================] - 2s 195ms/step - loss: 0.0753
# Epoch 17/100
# 8/8 [==============================] - 1s 160ms/step - loss: 0.0764
# Epoch 18/100
# 8/8 [==============================] - 1s 159ms/step - loss: 0.0756
# Epoch 19/100
# 8/8 [==============================] - 1s 137ms/step - loss: 0.0758
# Epoch 20/100
# 8/8 [==============================] - 1s 145ms/step - loss: 0.0708
# Epoch 21/100
# 8/8 [==============================] - 1s 148ms/step - loss: 0.0723
# Epoch 22/100
# 8/8 [==============================] - 1s 148ms/step - loss: 0.0742
# Epoch 23/100
# 8/8 [==============================] - 1s 145ms/step - loss: 0.0726
# Epoch 24/100
# 8/8 [==============================] - 1s 146ms/step - loss: 0.0720
# Epoch 25/100
# 8/8 [==============================] - 1s 168ms/step - loss: 0.0756
# Epoch 26/100
# 8/8 [==============================] - 1s 167ms/step - loss: 0.0704
# Epoch 27/100
# 8/8 [==============================] - 1s 152ms/step - loss: 0.0702
# Epoch 28/100
# 8/8 [==============================] - 1s 158ms/step - loss: 0.0718
# Epoch 29/100
# 8/8 [==============================] - 1s 146ms/step - loss: 0.0703
# Epoch 30/100
# 8/8 [==============================] - 1s 147ms/step - loss: 0.0702
# Epoch 31/100
# 8/8 [==============================] - 1s 138ms/step - loss: 0.0703
# Epoch 32/100
# 8/8 [==============================] - 1s 136ms/step - loss: 0.0748
# Epoch 33/100
# 8/8 [==============================] - 1s 149ms/step - loss: 0.0736
# Epoch 34/100
# 8/8 [==============================] - 1s 149ms/step - loss: 0.0704
# Epoch 35/100
# 8/8 [==============================] - 2s 200ms/step - loss: 0.0714
# Epoch 36/100
# 8/8 [==============================] - 2s 207ms/step - loss: 0.0726
# Epoch 37/100
# 8/8 [==============================] - 2s 219ms/step - loss: 0.0692
# Epoch 38/100
# 8/8 [==============================] - 1s 177ms/step - loss: 0.0688
# Epoch 39/100
# 8/8 [==============================] - 1s 176ms/step - loss: 0.0678
# Epoch 40/100
# 8/8 [==============================] - 1s 165ms/step - loss: 0.0675
# Epoch 41/100
# 8/8 [==============================] - 1s 175ms/step - loss: 0.0687
# Epoch 42/100
# 8/8 [==============================] - 1s 179ms/step - loss: 0.0684
# Epoch 43/100
# 8/8 [==============================] - 1s 155ms/step - loss: 0.0654
# Epoch 44/100
# 8/8 [==============================] - 1s 143ms/step - loss: 0.0669
# Epoch 45/100
# 8/8 [==============================] - 1s 155ms/step - loss: 0.0667
# Epoch 46/100
# 8/8 [==============================] - 1s 157ms/step - loss: 0.0687
# Epoch 47/100
# 8/8 [==============================] - 1s 151ms/step - loss: 0.0668
# Epoch 48/100
# 8/8 [==============================] - 1s 156ms/step - loss: 0.0651
# Epoch 49/100
# 8/8 [==============================] - 1s 157ms/step - loss: 0.0648
# Epoch 50/100
# 8/8 [==============================] - 1s 145ms/step - loss: 0.0637
# Epoch 51/100
# 8/8 [==============================] - 1s 142ms/step - loss: 0.0628
# Epoch 52/100
# 8/8 [==============================] - 1s 153ms/step - loss: 0.0602
# Epoch 53/100
# 8/8 [==============================] - 1s 152ms/step - loss: 0.0625
# Epoch 54/100
# 8/8 [==============================] - 1s 151ms/step - loss: 0.0606
# Epoch 55/100
# 8/8 [==============================] - 1s 144ms/step - loss: 0.0577
# Epoch 56/100
# 8/8 [==============================] - 1s 145ms/step - loss: 0.0575
# Epoch 57/100
# 8/8 [==============================] - 1s 153ms/step - loss: 0.0585
# Epoch 58/100
# 8/8 [==============================] - 1s 152ms/step - loss: 0.0557
# Epoch 59/100
# 8/8 [==============================] - 1s 152ms/step - loss: 0.0536
# Epoch 60/100
# 8/8 [==============================] - 1s 139ms/step - loss: 0.0517
# Epoch 61/100
# 8/8 [==============================] - 1s 137ms/step - loss: 0.0492
# Epoch 62/100
# 8/8 [==============================] - 1s 142ms/step - loss: 0.0500
# Epoch 63/100
# 8/8 [==============================] - 1s 151ms/step - loss: 0.0414
# Epoch 64/100
# 8/8 [==============================] - 1s 144ms/step - loss: 0.0415
# Epoch 65/100
# 8/8 [==============================] - 1s 165ms/step - loss: 0.0372
# Epoch 66/100
# 8/8 [==============================] - 1s 170ms/step - loss: 0.0367
# Epoch 67/100
# 8/8 [==============================] - 1s 172ms/step - loss: 0.0362
# Epoch 68/100
# 8/8 [==============================] - 1s 174ms/step - loss: 0.0275
# Epoch 69/100
# 8/8 [==============================] - 1s 161ms/step - loss: 0.0241
# Epoch 70/100
# 8/8 [==============================] - 1s 156ms/step - loss: 0.0244
# Epoch 71/100
# 8/8 [==============================] - 1s 154ms/step - loss: 0.0203
# Epoch 72/100
# 8/8 [==============================] - 1s 156ms/step - loss: 0.0218
# Epoch 73/100
# 8/8 [==============================] - 1s 156ms/step - loss: 0.0188
# Epoch 74/100
# 8/8 [==============================] - 1s 157ms/step - loss: 0.0171
# Epoch 75/100
# 8/8 [==============================] - 1s 160ms/step - loss: 0.0174
# Epoch 76/100
# 8/8 [==============================] - 1s 147ms/step - loss: 0.0157
# Epoch 77/100
# 8/8 [==============================] - 1s 149ms/step - loss: 0.0170
# Epoch 78/100
# 8/8 [==============================] - 1s 152ms/step - loss: 0.0142
# Epoch 79/100
# 8/8 [==============================] - 1s 153ms/step - loss: 0.0138
# Epoch 80/100
# 8/8 [==============================] - 1s 165ms/step - loss: 0.0138
# Epoch 81/100
# 8/8 [==============================] - 1s 148ms/step - loss: 0.0136
# Epoch 82/100
# 8/8 [==============================] - 1s 157ms/step - loss: 0.0109
# Epoch 83/100
# 8/8 [==============================] - 1s 148ms/step - loss: 0.0125
# Epoch 84/100
# 8/8 [==============================] - 1s 151ms/step - loss: 0.0121
# Epoch 85/100
# 8/8 [==============================] - 1s 150ms/step - loss: 0.0121
# Epoch 86/100
# 8/8 [==============================] - 1s 144ms/step - loss: 0.0101
# Epoch 87/100
# 8/8 [==============================] - 1s 145ms/step - loss: 0.0108
# Epoch 88/100
# 8/8 [==============================] - 1s 150ms/step - loss: 0.0110
# Epoch 89/100
# 8/8 [==============================] - 1s 150ms/step - loss: 0.0106
# Epoch 90/100
# 8/8 [==============================] - 1s 161ms/step - loss: 0.0090
# Epoch 91/100
# 8/8 [==============================] - 1s 168ms/step - loss: 0.0090
# Epoch 92/100
# 8/8 [==============================] - 1s 149ms/step - loss: 0.0097
# Epoch 93/100
# 8/8 [==============================] - 1s 131ms/step - loss: 0.0102
# Epoch 94/100
# 8/8 [==============================] - 1s 142ms/step - loss: 0.0084
# Epoch 95/100
# 8/8 [==============================] - 1s 156ms/step - loss: 0.0092
# Epoch 96/100
# 8/8 [==============================] - 1s 137ms/step - loss: 0.0090
# Epoch 97/100
# 8/8 [==============================] - 1s 147ms/step - loss: 0.0074
# Epoch 98/100
# 8/8 [==============================] - 1s 144ms/step - loss: 0.0081
# Epoch 99/100
# 8/8 [==============================] - 1s 150ms/step - loss: 0.0079
# Epoch 100/100
# 8/8 [==============================] - 1s 147ms/step - loss: 0.0077

# %%
print(regressorGRU.summary)
# Out:
# <bound method Model.summary of <keras.engine.sequential.Sequential object at 0x7f97a7ef8d60>>

# %%
dataset_total = pd.concat((df2.iloc[0:525,1:2],df2.iloc[525:657,1:2]),axis=0)
inputs = dataset_total[len(dataset_total)-len(test_set) - 60:].values
inputs = inputs.reshape(-1,1)
inputs  = sc.transform(inputs)

# %%
X_test = []
for i in range(60,192):
    X_test.append(inputs[i-60:i,0])
print(len(X_test))
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0],X_test.shape[1],1))
GRU_predicted = regressorGRU.predict(X_test)
GRU_predicted = sc.inverse_transform(GRU_predicted)
# Out:
# 132

# %%
print(GRU_predicted)
# Out:
# [[101.78371 ]
#  [101.984505]
#  [102.17887 ]
#  [102.36451 ]
#  [102.5422  ]
#  [102.710846]
#  [102.86819 ]
#  [103.012   ]
#  [103.14322 ]
#  [103.26361 ]
#  [103.37369 ]
#  [103.47576 ]
#  [103.57313 ]
#  [103.66911 ]
#  [103.76519 ]
#  [103.860245]
#  [103.95696 ]
#  [104.05767 ]
#  [104.162476]
#  [104.27002 ]
#  [104.38092 ]
#  [104.4946  ]
#  [104.610725]
#  [104.7281  ]
#  [104.85484 ]
#  [104.997375]
#  [105.15758 ]
#  [105.33416 ]
#  [105.52791 ]
#  [105.73718 ]
#  [105.95623 ]
#  [106.176544]
#  [106.39093 ]
#  [106.59554 ]
#  [106.78808 ]
#  [106.96848 ]
#  [107.13809 ]
#  [107.30356 ]
#  [107.47363 ]
#  [107.64807 ]
#  [107.808205]
#  [107.93397 ]
#  [108.02997 ]
#  [108.11573 ]
#  [108.20728 ]
#  [108.31793 ]
#  [108.459595]
#  [108.63092 ]
#  [108.81889 ]
#  [109.015945]
#  [109.222176]
#  [109.433556]
#  [109.639915]
#  [109.83281 ]
#  [109.999176]
#  [110.138885]
#  [110.2583  ]
#  [110.36452 ]
#  [110.4647  ]
#  [110.567215]
#  [110.67085 ]
#  [110.77655 ]
#  [110.89525 ]
#  [111.02931 ]
#  [111.1889  ]
#  [111.38972 ]
#  [111.628   ]
#  [111.88791 ]
#  [112.15055 ]
#  [112.39831 ]
#  [112.62075 ]
#  [112.82548 ]
#  [113.0205  ]
#  [113.206856]
#  [113.391045]
#  [113.57502 ]
#  [113.760475]
#  [113.94477 ]
#  [114.119026]
#  [114.27689 ]
#  [114.417435]
#  [114.52519 ]
#  [114.596436]
#  [114.636894]
#  [114.659546]
#  [114.67591 ]
#  [114.69529 ]
#  [114.72225 ]
#  [114.75064 ]
#  [114.77882 ]
#  [114.80917 ]
#  [114.842415]
#  [114.88092 ]
#  [114.92452 ]
#  [114.97247 ]
#  [115.02604 ]
#  [115.08421 ]
#  [115.14679 ]
#  [115.213   ]
#  [115.282875]
#  [115.3558  ]
#  [115.429726]
#  [115.48655 ]
#  [115.4831  ]
#  [115.40775 ]
#  [115.282394]
#  [115.1392  ]
#  [115.00215 ]
#  [114.883575]
#  [114.78852 ]
#  [114.71468 ]
#  [114.66454 ]
#  [114.653   ]
#  [114.68707 ]
#  [114.76605 ]
#  [114.882706]
#  [115.02513 ]
#  [115.18177 ]
#  [115.33502 ]
#  [115.47367 ]
#  [115.59592 ]
#  [115.71153 ]
#  [115.82852 ]
#  [115.95356 ]
#  [116.09046 ]
#  [116.23966 ]
#  [116.40075 ]
#  [116.57181 ]
#  [116.754456]
#  [116.95285 ]
#  [117.168434]
#  [117.39819 ]]

# %%
# Visualizing the results for GRU
plot_predictions(test_set,GRU_predicted)

# %%
# Evaluating GRU
return_analysis(test_set,GRU_predicted)
# Out:
# The root mean squared error is 5.85415298674836.
# The mean absolute error is 5.356487019856771.
# The mean absolute percentage error is 4.771658939314582. %
